# %%
import os, pymongo, pprint
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_mongodb import MongoDBAtlasVectorSearch
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pymongo import MongoClient
from ml.utils.mongo_vectorstore import MongoVectorStore
from ml.utils.generate_trend_vectors import summaries_by_gender, summaries_by_gender_and_date
from ml.data.get_images import return_images_links_by_gender_and_date, return_images_links_by_gender
from datetime import datetime
from dotenv import load_dotenv
from db import global_init

# %%
load_dotenv(dotenv_path="../.env")
global_init()

ATLAS_CONNECTION_STRING = os.getenv("MONGO_URI")
# Out:
# Connecting to MongoDB at mongodb+srv://mikeguyon98:RmWPuse65PYolM81@cluster0.6db0wou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0

# %%
# Connect to your Atlas cluster
client = MongoClient(ATLAS_CONNECTION_STRING)
# Define collection and index name
db_name = "langchain_db"
collection_name = "MaleTrend"
atlas_collection_men = client[db_name][collection_name]
atlas_collection_woman = client[db_name]["FemaleTrend"]
vector_search_index = "vector_index"

# %%
target_date = datetime(year=2024, month=5, day=2)

# %%
mongo_items = return_images_links_by_gender_and_date(target_date)
total_mongo_items = return_images_links_by_gender()
print(len(mongo_items["male"]))
print(len(total_mongo_items["male"]))
# Out:
# 118
# 158

# %%
# generate the docs
docs_men = summaries_by_gender_and_date("male", target_date)
docs_woman = summaries_by_gender_and_date("female", target_date)

# Print the first document
print(docs_men[0])
# Out:
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# Failed to generate trend summary for https://modemixer-images.s3.amazonaws.com/benedict-cumberbatchs-outfits-scream-for-fashion-see-pictures-here-7.jpg: Error code: 400 - {'error': {'message': 'Invalid image.', 'type': 'invalid_request_error', 'param': None, 'code': None}}
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# Failed to generate trend summary for https://modemixer-images.s3.amazonaws.com/GEncFSyXIAE81lV?format=jpg&name=large.jpg: Error code: 400 - {'error': {'message': 'Invalid image.', 'type': 'invalid_request_error', 'param': None, 'code': None}}
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# Failed to generate trend summary for https://modemixer-images.s3.amazonaws.com/George+Clooney+in+a+Blue+and+Gray+Suit.jpg: Error code: 400 - {'error': {'message': 'Invalid image.', 'type': 'invalid_request_error', 'param': None, 'code': None}}
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# Failed to generate trend summary for https://modemixer-images.s3.amazonaws.com/Screen%2Bshot%2B2014-09-01%2Bat%2B9.jpg: Error code: 400 - {'error': {'message': 'Invalid image.', 'type': 'invalid_request_error', 'param': None, 'code': None}}
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# Failed to generate trend summary for https://modemixer-images.s3.amazonaws.com/PF20%2520-%2520IN%2520MY%2520CHOOS%2520-%2520KATE%2520MOSS%2520-%2520HAWAII%2520V1.jpg: Error code: 400 - {'error': {'message': 'Invalid image.', 'type': 'invalid_request_error', 'param': None, 'code': None}}
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# Failed to generate trend summary for https://modemixer-images.s3.amazonaws.com/emma-stone-dress-21sept18-10.jpg: Error code: 400 - {'error': {'message': 'Invalid image.', 'type': 'invalid_request_error', 'param': None, 'code': None}}
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# <class 'openai.types.chat.chat_completion.Choice'>
# page_content="The individual in the image is wearing a casual yet sleek outfit featuring the following items:\n\n1. **Top**: A navy blue crew-neck sweater that fits well, highlighting a toned physique. The sweater is simple and void of any visible logos or patterns, giving it a clean look.\n\n2. **Pants**: He is wearing tailored grey trousers that seem to be made from a lightweight fabric, suitable for a smart-casual appearance. The fit is slim but not tight, offering a modern silhouette.\n\n3. **Shoes**: His footwear consists of black slip-on shoes, likely made of leather or a leather-like material. These shoes are versatile and suited for both casual and semi-formal wears.\n\n4. **Accessories**: He sports a wristwatch with a sizable, metallic face, which adds a touch of elegance to his overall attire. Additionally, he's wearing some rings, which contribute to his style by adding a personal touch.\n\n**Fashion Trends**:\n- **Smart-Casual Blend**: The ensemble effectively blends elements of formal and casual wear, which is a popular trend in men's fashion. This allows for flexibility in various social settings.\n- **Minimalism**: The outfit adheres to a minimalist aesthetic, using solid colors and simple designs without embellishments. This trend focuses on the quality and fit of clothing rather than complex patterns or bright colors.\n- **Tailored Fit**: Both the sweater and trousers fit well, emphasizing the importance of tailoring in contemporary fashion. Well-fitted" metadata={'source': 'https://modemixer-images.s3.amazonaws.com/4-1.jpg'}

# %%
men_texts = [doc.page_content for doc in docs_men]
men_metadata = [doc.metadata for doc in docs_men]

# %%
female_texts = [doc.page_content for doc in docs_woman]
female_metadata = [doc.metadata for doc in docs_woman]

# %% [markdown]
# ## Upload Texts

# %%
vector_db_men = MongoDBAtlasVectorSearch.from_connection_string(
    connection_string=ATLAS_CONNECTION_STRING,
    namespace="langchain_db.MaleTrend",
    embedding=OpenAIEmbeddings(disallowed_special=()),
    index_name=vector_search_index
)

# %%
vector_db_men.add_documents(documents=docs_men)
# Out:
# [ObjectId('6636d361d2aa2922f5e3d687'),
#  ObjectId('6636d361d2aa2922f5e3d688'),
#  ObjectId('6636d361d2aa2922f5e3d689'),
#  ObjectId('6636d361d2aa2922f5e3d68a'),
#  ObjectId('6636d361d2aa2922f5e3d68b'),
#  ObjectId('6636d361d2aa2922f5e3d68c'),
#  ObjectId('6636d361d2aa2922f5e3d68d'),
#  ObjectId('6636d361d2aa2922f5e3d68e'),
#  ObjectId('6636d361d2aa2922f5e3d68f'),
#  ObjectId('6636d361d2aa2922f5e3d690'),
#  ObjectId('6636d361d2aa2922f5e3d691'),
#  ObjectId('6636d361d2aa2922f5e3d692'),
#  ObjectId('6636d361d2aa2922f5e3d693'),
#  ObjectId('6636d361d2aa2922f5e3d694'),
#  ObjectId('6636d361d2aa2922f5e3d695'),
#  ObjectId('6636d361d2aa2922f5e3d696'),
#  ObjectId('6636d361d2aa2922f5e3d697'),
#  ObjectId('6636d361d2aa2922f5e3d698'),
#  ObjectId('6636d361d2aa2922f5e3d699'),
#  ObjectId('6636d361d2aa2922f5e3d69a'),
#  ObjectId('6636d361d2aa2922f5e3d69b'),
#  ObjectId('6636d361d2aa2922f5e3d69c'),
#  ObjectId('6636d361d2aa2922f5e3d69d'),
#  ObjectId('6636d361d2aa2922f5e3d69e'),
#  ObjectId('6636d361d2aa2922f5e3d69f'),
#  ObjectId('6636d361d2aa2922f5e3d6a0'),
#  ObjectId('6636d361d2aa2922f5e3d6a1'),
#  ObjectId('6636d361d2aa2922f5e3d6a2'),
#  ObjectId('6636d361d2aa2922f5e3d6a3'),
#  ObjectId('6636d361d2aa2922f5e3d6a4'),
#  ObjectId('6636d361d2aa2922f5e3d6a5'),
#  ObjectId('6636d361d2aa2922f5e3d6a6'),
#  ObjectId('6636d361d2aa2922f5e3d6a7'),
#  ObjectId('6636d361d2aa2922f5e3d6a8'),
#  ObjectId('6636d361d2aa2922f5e3d6a9'),
#  ObjectId('6636d361d2aa2922f5e3d6aa'),
#  ObjectId('6636d361d2aa2922f5e3d6ab'),
#  ObjectId('6636d361d2aa2922f5e3d6ac'),
#  ObjectId('6636d361d2aa2922f5e3d6ad'),
#  ObjectId('6636d361d2aa2922f5e3d6ae'),
#  ObjectId('6636d361d2aa2922f5e3d6af'),
#  ObjectId('6636d361d2aa2922f5e3d6b0'),
#  ObjectId('6636d361d2aa2922f5e3d6b1'),
#  ObjectId('6636d361d2aa2922f5e3d6b2'),
#  ObjectId('6636d361d2aa2922f5e3d6b3'),
#  ObjectId('6636d361d2aa2922f5e3d6b4'),
#  ObjectId('6636d361d2aa2922f5e3d6b5'),
#  ObjectId('6636d361d2aa2922f5e3d6b6'),
#  ObjectId('6636d361d2aa2922f5e3d6b7'),
#  ObjectId('6636d361d2aa2922f5e3d6b8'),
#  ObjectId('6636d361d2aa2922f5e3d6b9'),
#  ObjectId('6636d361d2aa2922f5e3d6ba'),
#  ObjectId('6636d361d2aa2922f5e3d6bb'),
#  ObjectId('6636d361d2aa2922f5e3d6bc'),
#  ObjectId('6636d361d2aa2922f5e3d6bd'),
#  ObjectId('6636d361d2aa2922f5e3d6be'),
#  ObjectId('6636d361d2aa2922f5e3d6bf'),
#  ObjectId('6636d361d2aa2922f5e3d6c0'),
#  ObjectId('6636d361d2aa2922f5e3d6c1'),
#  ObjectId('6636d361d2aa2922f5e3d6c2'),
#  ObjectId('6636d361d2aa2922f5e3d6c3'),
#  ObjectId('6636d361d2aa2922f5e3d6c4'),
#  ObjectId('6636d361d2aa2922f5e3d6c5'),
#  ObjectId('6636d361d2aa2922f5e3d6c6'),
#  ObjectId('6636d361d2aa2922f5e3d6c7'),
#  ObjectId('6636d361d2aa2922f5e3d6c8'),
#  ObjectId('6636d361d2aa2922f5e3d6c9'),
#  ObjectId('6636d361d2aa2922f5e3d6ca'),
#  ObjectId('6636d361d2aa2922f5e3d6cb'),
#  ObjectId('6636d361d2aa2922f5e3d6cc'),
#  ObjectId('6636d361d2aa2922f5e3d6cd'),
#  ObjectId('6636d361d2aa2922f5e3d6ce'),
#  ObjectId('6636d361d2aa2922f5e3d6cf'),
#  ObjectId('6636d361d2aa2922f5e3d6d0'),
#  ObjectId('6636d361d2aa2922f5e3d6d1'),
#  ObjectId('6636d361d2aa2922f5e3d6d2'),
#  ObjectId('6636d361d2aa2922f5e3d6d3'),
#  ObjectId('6636d361d2aa2922f5e3d6d4'),
#  ObjectId('6636d361d2aa2922f5e3d6d5'),
#  ObjectId('6636d361d2aa2922f5e3d6d6'),
#  ObjectId('6636d361d2aa2922f5e3d6d7'),
#  ObjectId('6636d361d2aa2922f5e3d6d8'),
#  ObjectId('6636d361d2aa2922f5e3d6d9'),
#  ObjectId('6636d361d2aa2922f5e3d6da'),
#  ObjectId('6636d361d2aa2922f5e3d6db'),
#  ObjectId('6636d361d2aa2922f5e3d6dc'),
#  ObjectId('6636d361d2aa2922f5e3d6dd'),
#  ObjectId('6636d361d2aa2922f5e3d6de'),
#  ObjectId('6636d361d2aa2922f5e3d6df'),
#  ObjectId('6636d361d2aa2922f5e3d6e0'),
#  ObjectId('6636d361d2aa2922f5e3d6e1'),
#  ObjectId('6636d361d2aa2922f5e3d6e2'),
#  ObjectId('6636d361d2aa2922f5e3d6e3'),
#  ObjectId('6636d361d2aa2922f5e3d6e4'),
#  ObjectId('6636d361d2aa2922f5e3d6e5'),
#  ObjectId('6636d361d2aa2922f5e3d6e6'),
#  ObjectId('6636d361d2aa2922f5e3d6e7'),
#  ObjectId('6636d361d2aa2922f5e3d6e8'),
#  ObjectId('6636d361d2aa2922f5e3d6e9'),
#  ObjectId('6636d361d2aa2922f5e3d6ea'),
#  ObjectId('6636d363d2aa2922f5e3d6eb'),
#  ObjectId('6636d363d2aa2922f5e3d6ec'),
#  ObjectId('6636d363d2aa2922f5e3d6ed'),
#  ObjectId('6636d363d2aa2922f5e3d6ee'),
#  ObjectId('6636d363d2aa2922f5e3d6ef'),
#  ObjectId('6636d363d2aa2922f5e3d6f0'),
#  ObjectId('6636d363d2aa2922f5e3d6f1'),
#  ObjectId('6636d363d2aa2922f5e3d6f2'),
#  ObjectId('6636d363d2aa2922f5e3d6f3'),
#  ObjectId('6636d363d2aa2922f5e3d6f4'),
#  ObjectId('6636d363d2aa2922f5e3d6f5'),
#  ObjectId('6636d363d2aa2922f5e3d6f6'),
#  ObjectId('6636d363d2aa2922f5e3d6f7'),
#  ObjectId('6636d363d2aa2922f5e3d6f8')]

# %%
vector_db_woman = MongoDBAtlasVectorSearch.from_connection_string(
    connection_string=ATLAS_CONNECTION_STRING,
    namespace="langchain_db.FemaleTrend",
    embedding=OpenAIEmbeddings(disallowed_special=()),
    index_name=vector_search_index
)

# %%
vector_db_woman.add_documents(documents=docs_woman)
# Out:
# [ObjectId('6636d67ed2aa2922f5e3d7e3'),
#  ObjectId('6636d67ed2aa2922f5e3d7e4'),
#  ObjectId('6636d67ed2aa2922f5e3d7e5'),
#  ObjectId('6636d67ed2aa2922f5e3d7e6'),
#  ObjectId('6636d67ed2aa2922f5e3d7e7'),
#  ObjectId('6636d67ed2aa2922f5e3d7e8'),
#  ObjectId('6636d67ed2aa2922f5e3d7e9'),
#  ObjectId('6636d67ed2aa2922f5e3d7ea'),
#  ObjectId('6636d67ed2aa2922f5e3d7eb'),
#  ObjectId('6636d67ed2aa2922f5e3d7ec'),
#  ObjectId('6636d67ed2aa2922f5e3d7ed'),
#  ObjectId('6636d67ed2aa2922f5e3d7ee'),
#  ObjectId('6636d67ed2aa2922f5e3d7ef'),
#  ObjectId('6636d67ed2aa2922f5e3d7f0'),
#  ObjectId('6636d67ed2aa2922f5e3d7f1'),
#  ObjectId('6636d67ed2aa2922f5e3d7f2'),
#  ObjectId('6636d67ed2aa2922f5e3d7f3'),
#  ObjectId('6636d67ed2aa2922f5e3d7f4'),
#  ObjectId('6636d67ed2aa2922f5e3d7f5'),
#  ObjectId('6636d67ed2aa2922f5e3d7f6'),
#  ObjectId('6636d67ed2aa2922f5e3d7f7'),
#  ObjectId('6636d67ed2aa2922f5e3d7f8'),
#  ObjectId('6636d67ed2aa2922f5e3d7f9'),
#  ObjectId('6636d67ed2aa2922f5e3d7fa'),
#  ObjectId('6636d67ed2aa2922f5e3d7fb'),
#  ObjectId('6636d67ed2aa2922f5e3d7fc'),
#  ObjectId('6636d67ed2aa2922f5e3d7fd'),
#  ObjectId('6636d67ed2aa2922f5e3d7fe'),
#  ObjectId('6636d67ed2aa2922f5e3d7ff'),
#  ObjectId('6636d67ed2aa2922f5e3d800'),
#  ObjectId('6636d67ed2aa2922f5e3d801'),
#  ObjectId('6636d67ed2aa2922f5e3d802'),
#  ObjectId('6636d67ed2aa2922f5e3d803'),
#  ObjectId('6636d67ed2aa2922f5e3d804'),
#  ObjectId('6636d67ed2aa2922f5e3d805'),
#  ObjectId('6636d67ed2aa2922f5e3d806'),
#  ObjectId('6636d67ed2aa2922f5e3d807'),
#  ObjectId('6636d67ed2aa2922f5e3d808'),
#  ObjectId('6636d67ed2aa2922f5e3d809'),
#  ObjectId('6636d67ed2aa2922f5e3d80a'),
#  ObjectId('6636d67ed2aa2922f5e3d80b'),
#  ObjectId('6636d67ed2aa2922f5e3d80c'),
#  ObjectId('6636d67ed2aa2922f5e3d80d'),
#  ObjectId('6636d67ed2aa2922f5e3d80e'),
#  ObjectId('6636d67ed2aa2922f5e3d80f'),
#  ObjectId('6636d67ed2aa2922f5e3d810'),
#  ObjectId('6636d67ed2aa2922f5e3d811'),
#  ObjectId('6636d67ed2aa2922f5e3d812'),
#  ObjectId('6636d67ed2aa2922f5e3d813'),
#  ObjectId('6636d67ed2aa2922f5e3d814'),
#  ObjectId('6636d67ed2aa2922f5e3d815'),
#  ObjectId('6636d67ed2aa2922f5e3d816'),
#  ObjectId('6636d67ed2aa2922f5e3d817'),
#  ObjectId('6636d67ed2aa2922f5e3d818'),
#  ObjectId('6636d67ed2aa2922f5e3d819'),
#  ObjectId('6636d67ed2aa2922f5e3d81a'),
#  ObjectId('6636d67ed2aa2922f5e3d81b'),
#  ObjectId('6636d67ed2aa2922f5e3d81c'),
#  ObjectId('6636d67ed2aa2922f5e3d81d'),
#  ObjectId('6636d67ed2aa2922f5e3d81e'),
#  ObjectId('6636d67ed2aa2922f5e3d81f'),
#  ObjectId('6636d67ed2aa2922f5e3d820'),
#  ObjectId('6636d67ed2aa2922f5e3d821'),
#  ObjectId('6636d67ed2aa2922f5e3d822'),
#  ObjectId('6636d67ed2aa2922f5e3d823'),
#  ObjectId('6636d67ed2aa2922f5e3d824'),
#  ObjectId('6636d67ed2aa2922f5e3d825'),
#  ObjectId('6636d67ed2aa2922f5e3d826'),
#  ObjectId('6636d67ed2aa2922f5e3d827'),
#  ObjectId('6636d67ed2aa2922f5e3d828'),
#  ObjectId('6636d67ed2aa2922f5e3d829'),
#  ObjectId('6636d67ed2aa2922f5e3d82a'),
#  ObjectId('6636d67ed2aa2922f5e3d82b'),
#  ObjectId('6636d67ed2aa2922f5e3d82c'),
#  ObjectId('6636d67ed2aa2922f5e3d82d'),
#  ObjectId('6636d67ed2aa2922f5e3d82e'),
#  ObjectId('6636d67ed2aa2922f5e3d82f'),
#  ObjectId('6636d67ed2aa2922f5e3d830'),
#  ObjectId('6636d67ed2aa2922f5e3d831'),
#  ObjectId('6636d67ed2aa2922f5e3d832'),
#  ObjectId('6636d67ed2aa2922f5e3d833'),
#  ObjectId('6636d67ed2aa2922f5e3d834'),
#  ObjectId('6636d67ed2aa2922f5e3d835'),
#  ObjectId('6636d67ed2aa2922f5e3d836'),
#  ObjectId('6636d67ed2aa2922f5e3d837'),
#  ObjectId('6636d67ed2aa2922f5e3d838'),
#  ObjectId('6636d67ed2aa2922f5e3d839'),
#  ObjectId('6636d67ed2aa2922f5e3d83a'),
#  ObjectId('6636d67ed2aa2922f5e3d83b'),
#  ObjectId('6636d67ed2aa2922f5e3d83c'),
#  ObjectId('6636d67ed2aa2922f5e3d83d'),
#  ObjectId('6636d67ed2aa2922f5e3d83e'),
#  ObjectId('6636d67ed2aa2922f5e3d83f'),
#  ObjectId('6636d67ed2aa2922f5e3d840'),
#  ObjectId('6636d67ed2aa2922f5e3d841'),
#  ObjectId('6636d67ed2aa2922f5e3d842'),
#  ObjectId('6636d67ed2aa2922f5e3d843'),
#  ObjectId('6636d67ed2aa2922f5e3d844'),
#  ObjectId('6636d67ed2aa2922f5e3d845'),
#  ObjectId('6636d67ed2aa2922f5e3d846'),
#  ObjectId('6636d683d2aa2922f5e3d847'),
#  ObjectId('6636d683d2aa2922f5e3d848'),
#  ObjectId('6636d683d2aa2922f5e3d849'),
#  ObjectId('6636d683d2aa2922f5e3d84a'),
#  ObjectId('6636d683d2aa2922f5e3d84b'),
#  ObjectId('6636d683d2aa2922f5e3d84c'),
#  ObjectId('6636d683d2aa2922f5e3d84d'),
#  ObjectId('6636d683d2aa2922f5e3d84e'),
#  ObjectId('6636d683d2aa2922f5e3d84f'),
#  ObjectId('6636d683d2aa2922f5e3d850'),
#  ObjectId('6636d683d2aa2922f5e3d851'),
#  ObjectId('6636d683d2aa2922f5e3d852'),
#  ObjectId('6636d683d2aa2922f5e3d853'),
#  ObjectId('6636d683d2aa2922f5e3d854')]

# %%
vector_search_men = MongoDBAtlasVectorSearch.from_documents(
    documents = docs_men,
    embedding = OpenAIEmbeddings(disallowed_special=()),
    collection = atlas_collection_men,
    index_name = vector_search_index
)

# %%
vector_search_woman = MongoDBAtlasVectorSearch.from_documents(
    documents = docs_woman,
    embedding = OpenAIEmbeddings(disallowed_special=()),
    collection = atlas_collection_woman,
    index_name = vector_search_index
)

# %%
query = "East coast styled womans jacket"
results = vector_search_woman.similarity_search(query)
pprint.pprint(results)
# Out:
# [Document(page_content='The person in the image is wearing a stylish and contemporary ensemble characterized by a mix of classic and modern fashion elements. Here are the key items of clothing and accessories:\n\n1. **Leather Jacket**: The standout item is a vibrant orange-red leather jacket with a glossy finish. The jacket features a slightly oversized fit with a simple, structured collar.\n\n2. **Brown Cropped Top**: Underneath the jacket, she sports a tight-fitting brown cropped top. The top appears to be made from a soft, stretchable fabric, enhancing the fit-and-flare silhouette.\n\n3. **Black High-Waisted Jeans**: Complementing the top, she’s wearing black high-waisted jeans that adopt a relaxed fit. This choice adds a casual yet chic vibe to her overall outfit.\n\n4. **Black Loafers**: On her feet, there are polished black loafers which match well with the casual sophistication of her look.\n\n5. **Accessories**: She is carrying a large black handbag and a secondary smaller, fur-patterned bag hanging from her shoulder. Her look is accessorized with large hoop earrings with an intricate design, adding an elegant touch.\n\n6. **Fashion Trends**: This ensemble reflects several fashion trends:\n   - **Layering and Texture Mix**: Combining leather with soft fabric creates a rich textural contrast that’s quite popular in contemporary fashion.\n   - **Bold Colors with Neutral Tones**: The bright jacket against the backdrop of more subdued colors (brown and black', metadata={'_id': ObjectId('6632cf147ca7dd37e0ea4070'), 'source': 'https://modemixer-images.s3.amazonaws.com/Bella-Hadid-Street-Style-at-New-York-Fashion-Week.jpg'}),
#  Document(page_content='The image showcases several chic and refined clothing items along with a classic and luxurious fashion appeal. Here’s a breakdown of each piece:\n\n1. **Hat**: The person is wearing a black bucket hat, which is in vogue for its streetwear aesthetic mixed with high fashion influences.\n\n2. **Oversized Puffer Coat**: The most striking ensemble piece is an oversized puffer coat that features a textured pattern. It has a belt cinched at the waist, enhancing the silhouette despite the voluminous upper design. This kind of dramatic volume is a trending style known for adding a modern twist to traditional outerwear.\n\n3. **Gloves**: She wears elegant black leather gloves, signifying a touch of traditional sophistication.\n\n4. **Pencil Skirt**: The coat is paired with a plain black fitted pencil skirt, which offers a sleek contrast to the voluminous top, maintaining a balanced and refined look. \n\n5. **High-Heel Shoes**: She sports pointed high-heeled shoes in white, which is an eye-catching choice that starkly contrasts with the rest of the dark outfit. The ankle is adorned with what seems like a belt-style accessory over the shoe, keeping in line with the chic and accessorized styling of the whole outfit.\n\n6. **Handbag**: A black quilted handbag complements the outfit, staying true to the luxurious and high-fashion aesthetic. The quilted design is a classic element, often associated with timeless luxury.\n\n7. **Jewelry', metadata={'_id': ObjectId('6632cf147ca7dd37e0ea4066'), 'source': 'https://modemixer-images.s3.amazonaws.com/dior-4-gty-er-240122_1705952431878_hpEmbed_9x14.jpg'}),
#  Document(page_content="In the image you've provided, the individual is wearing the following items:\n\n1. **Hat**: A yellow baseball cap, which gives a casual and sporty look. Baseball caps are often used in casual outfits and are good for concealing hair on less formal occasions or for protecting the face from the sun.\n\n2. **Jacket**: A black hooded windbreaker jacket with a visible logo of The North Face on the right chest area. This type of jacket is popular for its practicality and sporty aesthetic, providing lightweight protection from wind and light rain, making it a suitable choice for transitional weather.\n\n3. **Inner Top**: Beneath the windbreaker, there appears to be a light grey hoodie. Layering like this is not only practical for variable temperatures but also contributes to a relaxed, streetwear-influenced style.\n\n4. **Pants**: The person is wearing light grey jeans, which match the casual and comfortable theme of the outfit. Jeans are a staple item in many wardrobes due to their versatility.\n\n5. **Bag**: A small pale pink crossbody bag with a noticeable logo that looks to be from Roger Vivier (judging by the visible RV initials). This adds a touch of soft color contrast to the outfit and suggests a blend of practicality with a nod to luxury accessories.\n\n6. **Smartphone**: Held in hand, indicating a connection with technology and its importance in everyday life.\n\nIn terms of fashion trends, this look showcases several:\n-", metadata={'_id': ObjectId('6632cf147ca7dd37e0ea4074'), 'source': 'https://modemixer-images.s3.amazonaws.com/ariana-grande-out-and-about-in-london-04-16-2023-9.jpg'}),
#  Document(page_content="The individual in the image is wearing an ensemble that exhibits contemporary high fashion trends with an inventive touch. Here's a breakdown of the clothing items and the fashion trends displayed:\n\n1. **Top**: The subject is wearing a crisp white button-down shirt. It appears tailored and is designed to have a classic and sleek look, indicative of a timeless fashion staple. \n\n2. **Corset-style Bodice**: Over the shirt, she wears a sophisticated, structured corset-style bodice. The bodice has floral and toile print in a blue monochrome palette, which adds a modern juxtaposition of traditional prints on a contemporary silhouette. The front of the bodice features a series of metal hook closures that add a metallic touch and enhance the garment's textured appearance.\n\n3. **Shorts**: The bodice extends into high-waisted shorts made of the same printed fabric as the bodice, creating a cohesive and streamlined look. The shorts are form-fitting, emphasizing a structured and tailored fashion trend.\n\n4. **Boots**: She is wearing high, laced boots in a matching blue color that follows the monochrome theme. The boots are made from a glossy leather material, which introduces a luxe, polished finish to the outfit. The knee-high length of the boots adds a dynamic and dramatic flair to the overall look.\n\n5. **Bag**: In addition, she carries a large, structured tote bag in the same blue leather material. The bag embodies simplicity and functionality infused with high fashion aesthetics", metadata={'_id': ObjectId('6632cf147ca7dd37e0ea406f'), 'source': 'https://modemixer-images.s3.amazonaws.com/1_6_(18)-gthumb-gwdata1200-ghdata1200-gfitdatamax.jpg'})]

# %% [markdown]
# ## Dalle Generation for Item Images

# %%
#call dalle
from openai import OpenAI
client = OpenAI()

def generate_items(prompt):
    response = client.images.generate(
        model="dall-e-3",
        prompt=prompt,
        size="1024x1024",
        quality="standard",
        n=1,
    )
    return response.data[0].url

# %%
def get_context(query, gender):
    if gender == "female":
        results = vector_search_woman.similarity_search(query, k=2)
    else:
        results = vector_search_men.similarity_search(query, k=2)
    print(results)
    context = ""
    for result in results:
        context += result.page_content + " "
    prompt = f"""
CONTEXT: 
The Following is a trending celebrity outfit with similar styles to the search query:
Use the context as inspiration to generate a new outfit that is unique and stylish.
{context}

QUERY: 
{query}

DIRECTIONS:
Generate a new clothing items that matches the user query. Make sure to only include the item \
and not the person wearing it. JUST THE CLOTHING ITEM, NOTHING ELSE AND MAKE SURE IT IS NOT FOLDED. Use a plain white background for the image with nothing in the image except the clothing item.
"""
    return prompt

# %%
prompt = get_context("An elegant sleeveless and short linen beach dress", "female")

items = generate_items(prompt)
print(items)
# Out:
# [Document(page_content='The person in the image is wearing an elegant black strapless gown. The dress features a heart-shaped bodice that accentuates the neckline, with a bow detail at the waist that adds a touch of sophistication and visual interest. The dress has a full, voluminous skirt that elegantly flows to the floor, creating a dramatic silhouette. Additionally, the person is accessorizing with a sparkling, slender necklace, which adds a luxurious touch to the ensemble.\n\nThe fashion trends displayed in this outfit include a classic strapless design that showcases the shoulders and neckline, creating a graceful and timeless look. The bow detail at the waistline is a nod to femininity and adds a couture-like vibe to the attire. The voluminous skirt of the gown leans into the trend of statement silhouettes that have been popular on red carpets, signifying a blend of both glamour and traditional elegance. The overall aesthetic is one of refined sophistication with a strong emphasis on classic beauty and tailored elegance.', metadata={'_id': ObjectId('6632cf147ca7dd37e0ea406a'), 'source': 'https://modemixer-images.s3.amazonaws.com/zendaya-emmys-arrivals-091222-8fac9aba4d2e4f469dc47eb5aba08276.jpg'}), Document(page_content="The person in the image is wearing an elegant and striking evening gown that combines several fashion-forward elements:\n\n1. **Dress**: The dress features a deep V-neckline that adds a bold and sensual element to the ensemble. It has a fitted black velvet bodice that transitions into a flowing, pleated skirt with a high slit up the leg. The skirt is notable for its gradient color transition from black at the top to a light gray or silver at the hem.\n\n2. **Sleeves**: The gown includes long, sheer sleeves that start from the shoulder and extend into a more opaque fabric as it reaches the wrists, enhancing the outfit's dramatic flair.\n\n3. **Footwear**: She wears simple yet classy black high-heeled sandals with a minimalist strap design, which complements the elegance of the dress without taking away from the details of the gown.\n\n**Fashion Trends**: \n- **High Slits**: The high slit in the gown is a fashionable choice that adds a touch of allure and modernity, often seen in red carpet styles.\n- **Sheer Fabric**: The use of sheer fabric in the sleeves is a contemporary trend that adds a layer of sophistication and texture to outfits.\n- **Velvet and Gradient Fabrics**: The combination of velvet with a gradient color fabric provides a luxurious feel and a visually appealing contrast, perfect for formal events.\n\nOverall, this outfit is a perfect example of modern elegance, combining classic materials like velvet with bold design elements such as a deep V-neck", metadata={'_id': ObjectId('6632cf147ca7dd37e0ea406d'), 'source': 'https://modemixer-images.s3.amazonaws.com/ac7b892c70284f66b85779f4e2bc2e56.jpg'})]
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-roK2uNkUZhg6dp9g19NmsDdC/user-DhpDCRCbWbMmyX4Q8hXARNXU/img-28PkFZVU9ybXGZjT7Tjn1Zdt.png?st=2024-05-02T00%3A28%3A50Z&se=2024-05-02T02%3A28%3A50Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-05-01T23%3A38%3A05Z&ske=2024-05-02T23%3A38%3A05Z&sks=b&skv=2021-08-06&sig=P9abYKswIkMlfWvR1rYEwi21laHmTzLDrqdRxq/E2Bk%3D

# %% [markdown]
# ## Delete Accidental Woman

# %%
from pymongo import MongoClient

# # Connect to MongoDB (adjust the connection string as necessary)
# client = MongoClient('mongodb://localhost:27017/')
# db = client['your_database_name']  # Replace 'your_database_name' with the name of your database
# collection = db['your_collection_name']  # Replace 'your_collection_name' with the name of your collection
client = MongoClient(ATLAS_CONNECTION_STRING)
# Define collection and index name
db_name = "langchain_db"
collection_name = "MaleTrend"
atlas_collection_men = client[db_name][collection_name]
atlas_collection_woman = client[db_name]["FemaleTrend"]
vector_search_index = "vector_index"

# docs_woman contains the text fields of the documents you want to delete
t_woman = [doc.page_content for doc in docs_woman]  # Example text values

# Loop through each text value and delete matching documents
for text_value in t_woman:
    atlas_collection_men.delete_many({"text": text_value})

# Close the MongoDB connection
client.close()
