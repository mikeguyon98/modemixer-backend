# %%
import os, pymongo, pprint
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_mongodb import MongoDBAtlasVectorSearch
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pymongo import MongoClient
from app.ml.utils.mongo_vectorstore import MongoVectorStore
from app.ml.utils.generate_trend_vectors import summaries_by_gender
from dotenv import load_dotenv
from db import global_init

# %%
load_dotenv(dotenv_path="../.env")
global_init()
# Out:
# Connecting to MongoDB at mongodb+srv://mikeguyon98:RmWPuse65PYolM81@cluster0.6db0wou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0

# %%
import requests
from bs4 import BeautifulSoup
import boto3
from dotenv import load_dotenv
import os
import datetime
from pymongo import MongoClient
from PIL import Image
import io

client = MongoClient(os.getenv("MONGO_URI"))
db = client["test"]

# Convert any image to JPEG
def convert_to_jpeg(image):
    if image.format != 'JPEG':
        image = image.convert('RGB')
    img_byte_arr = io.BytesIO()
    image.save(img_byte_arr, format='JPEG')
    return img_byte_arr

# Resize image if larger than 20MB
def resize_image(image, max_size_mb=20):
    img_byte_arr = io.BytesIO()
    image.save(img_byte_arr, format='JPEG')
    img_byte_arr.seek(0)

    if img_byte_arr.getbuffer().nbytes > max_size_mb * 1024 * 1024:  # Convert MB to bytes
        factor = (max_size_mb * 1024 * 1024 / img_byte_arr.getbuffer().nbytes)**0.5
        new_size = (int(image.size[0] * factor), int(image.size[1] * factor))
        image = image.resize(new_size, Image.ANTIALIAS)
        img_byte_arr = io.BytesIO()
        image.save(img_byte_arr, format='JPEG')

    return img_byte_arr


def search_images_bing(api_key, term, count=10):
    print(api_key)
    print(count)
    url = "https://api.bing.microsoft.com/v7.0/images/search"
    headers = {"Ocp-Apim-Subscription-Key": api_key}
    params = {"q": term, "imageType": "photo", "count": count}
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    search_results = response.json()
    image_urls = [img["contentUrl"] for img in search_results["value"]]
    return image_urls


def upload_image_to_s3(img_byte_arr, bucket_name, file_name):
    session = boto3.Session(
        aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
        aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
        region_name=os.getenv("AWS_REGION"),
    )
    s3 = session.client("s3")
    
    try:
        s3.upload_fileobj(io.BytesIO(img_byte_arr.getvalue()), bucket_name, file_name)
        print(f"Successfully uploaded {file_name} to S3 bucket {bucket_name}")
        # Get the public URL for the uploaded image
        public_url = f"https://{bucket_name}.s3.amazonaws.com/{file_name}"
        return public_url
    except Exception as e:
        print(f"Failed to upload {file_name}: {e}")
        return None

def process_and_upload_image(image_url, bucket_name):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
    response = requests.get(image_url, stream=True, headers=headers)
    try:
        response.raise_for_status()
        image = Image.open(response.raw)
        img_byte_arr = convert_to_jpeg(image)
        img_byte_arr = resize_image(Image.open(img_byte_arr))
        file_name = f"{image_url.split('/')[-1].split('.')[0]}.jpg"
        return upload_image_to_s3(img_byte_arr, bucket_name, file_name)
    except Exception as e:
        print(f"Error processing image {image_url}: {e}")
        return None



def get_images(references : dict) -> None:
    for man in references["male"]:
        process_image(man, "male")
    for female in references["female"]:
        process_image(female, "female")
    print("Images uploaded successfully")

def process_image(person: str, gender: str) -> None:
    keyword = f"{person} outfits {datetime.datetime.now().year}"
    total_images = 4
    bucket_name = "modemixer-images"
    image_urls = search_images_bing(os.getenv("BING_SEARCH_API_KEY"), keyword, count=total_images)
    for image_url in image_urls:
        s3_url = process_and_upload_image(image_url, bucket_name)
        if s3_url:
            document = {
                "url": s3_url,
                "gender": gender,
                "created_at": datetime.datetime.now(),
            }
            db.FashionReference.insert_one(document)
            if db.FashionReference.find_one(document):
                print("Document inserted successfully")
            else:
                print("Failed to insert document")
        else:
            print(f"Failed to process image {image_url}")

# %%
print(search_images_bing(os.getenv("BING_SEARCH_API_KEY"), "Kylie Jenner outfits"))
# Out:
# e0a93276ad3a4757bdb2184a1d582287
# 10
# ['https://media.glamour.com/photos/5e12384f297e2e00083c5df0/master/w_1600%2Cc_limit/GettyImages-1074669474.jpg', 'http://cos.h-cdn.co/assets/16/18/1462488249-gettyimages-527501278.jpg', 'https://www.hawtcelebs.com/wp-content/uploads/2019/02/kylie-jenner-at-pre-grammy-gala-and-grammy-salute-in-beverly-hills-02-09-2019-2.jpg', 'https://celebmafia.com/wp-content/uploads/2020/04/kylie-jenner-street-style-beverly-hills-04-24-2020-1.jpg', 'https://celebmafia.com/wp-content/uploads/2019/12/kylie-jenner-night-out-style-december-2019-6.jpg', 'https://celebmafia.com/wp-content/uploads/2016/02/kylie-jenner-street-style-out-in-new-york-city-february-2016-3.jpg', 'https://celebmafia.com/wp-content/uploads/2016/02/kylie-jenner-street-style-out-in-new-york-city-february-2016-1.jpg', 'https://celebmafia.com/wp-content/uploads/2017/02/kylie-jenner-heads-to-a-store-in-beverly-hills-2-27-2017-1.jpg', 'https://celebmafia.com/wp-content/uploads/2015/03/kylie-jenner-style-leaving-a-restaurant-in-calabasas-march-2015_1.jpg', 'https://celebmafia.com/wp-content/uploads/2015/03/kylie-jenner-style-leaving-a-restaurant-in-calabasas-march-2015_4.jpg']

# %%
references = {
    "male" : [
        "David Beckham",
        "Timothée Chalamet",
        "Donald Glover",
        "Lil Nas X",
        "Troye Sivan",
        "Pharrell Williams",
        "Brad Pitt",
        "ASAP Rocky",
        "Justin Bieber",
        "Harry Styles",
    ],
    "female" : [
        "Rihanna",
        "Zendaya",
        "Bella Hadid",
        "Ariana Grande",
        "Billie Eilish",
        "Dua Lipa",
        "Selena Gomez",
        "Kylie Jenner",
        "Taylor Swift",
        "Beyonce",
    ]
}

# %%
get_images(references)
# Out:
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded 20200430-David-02.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded beckham-outfits-8.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded David-Beckham-formal-style.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 20200430-David-07.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded gettyimages-1178964377_p.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded GettyImages-1388058563.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded c1c834fc6935ebc6213020da9525c724.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded timothee-chalamet-golden-globes-2024-06.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded donald-glover-vanity-fair-031223-62c8b710343242cc91a9de03ab412338.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded Donald-Glover-Wore-Saint-Laurent-To-The-2023-Golden-Globe-Awards.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded Donald-glover-style-featured.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 13MOST-STYLISH-VF-OSCARS-01-qvct-jumbo.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded 210914_gma_digital_LilNasXMET_hpMain_1x1_992.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded iil-nas-x-iconic-looks-1-d25ba33dac7d47d4a4ab1d765b6bec04.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded GettyImages-1339914552.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded eac1cebc7e8b9e69d05030c16d0cb64d.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded troye-sivan-prada-show-2.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded troye-sivan-prada-show.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded GettyImages-1339928309.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded IMG_7202-834x1024.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded DAN00659.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 7454849-pharrell-williams-defile-de-mode-mascu-580x0-2.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 7372119-pharrell-williams-photocall-du-defile-580x0-2.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded mens-creative-director-of-louis-vuitton-pharrell-williams-news-photo-1687172815.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded 1469295410.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 1642f664c212d32a2f7be76b1f2fffed.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 54776fd0f495947b2318fe499b4bb009.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 3c707a5f20364acb263e7306cd88232b.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded asap-rocky-style-outfit-fashion-20-of-51.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 9739f0392edd57339a130e45ddf04e8b.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 1644666184316.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded gettyimages-644295220.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded Justin-Bieber-Best-Style-Fashion-16-of-20-1200x1600.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded justin-biebers-style-is-phenomenal-and-he-proves-it-every-single-time-have-a-look-3.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 33357934-8749425-image-m-75_1600471126333.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 1a4155c0b6a23acdb0ae5b2d632a82af.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded Every-Outfit-Harry-Styles-Wore-2023-Grammys-003.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded Every-Outfit-Harry-Styles-Wore-2023-Grammys-005.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded harry-styles-jumpsuit-grammys-2023.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded harry-styles-grammys-2023.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded dior-4-gty-er-240122_1705952431878_hpEmbed_9x14.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded tmp_AIcUhZ_51f96456df16c6f6_GettyImages-1204749631-1500x2048.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded BGUS_2349573_006.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 3e5594aa07386a018052708c13304316.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded zendaya-emmys-arrivals-091222-8fac9aba4d2e4f469dc47eb5aba08276.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded zendaya-29.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded zendaya-coleman-oscars-2022-red-carpet-18.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded ac7b892c70284f66b85779f4e2bc2e56.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded bella-hadid-9.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 1_6_(18)-gthumb-gwdata1200-ghdata1200-gfitdatamax.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded Bella-Hadid-Street-Style-at-New-York-Fashion-Week.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded bella-hadid-at-versace-runway-show-at-milan-fashion-week-01-12-2019-8.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded ariana-grande-cynthia-erivo-oscars-2024-billboard-1548.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded ariana-grande-red-carpet-lilac-dress.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded gettyimages-1235152419.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded ariana-grande-out-and-about-in-london-04-16-2023-9.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded b1d367faefae6012d8c0d695b501d51f.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 9b3df3eb5a28c362001c89d2b4de0ead.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded bd9084307dd4ed528af4d497269cfb63.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 1010071776.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded dua-lipa-makes-her-arrival-at-met-gala-2023-02.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded bce9d2757a10f9abaffc224c76586c18.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded 1e0b67d4604ebde04ffa34.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded cc7d788f0cc4b1a39894201fc9d0181c.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded selena-gomez-2023-golden-globe-arrivals-74027649f21c4669929c4eb4540b4616.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded holding-selena-gomez-celebrity-style.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded ee2bc64572536368dddc9200e916e1bd.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded selena-gomez-mtv-vmas-carpet-09.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded gettyimages-1958033002-65b1656743100.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded GettyImages-1429662818.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded kyliejennerverawangjeans.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded kylie-jenner-street-style-out-in-new-york-city-february-2016-3.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded taylor-swift-2023-globes-arrivals-4471fd9f4e4f4a368ae074fe43eee58f.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded taylor-swift-attends-66th-grammy-75968672.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded golden-globes-taylor-swift.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded taylor-swift-grammys-2024-arrivals-45b0b60031d747a296a15bcbf22e7f20.jpg to S3 bucket modemixer-images
# Document inserted successfully
# e0a93276ad3a4757bdb2184a1d582287
# 4
# Successfully uploaded beyonce-tour9-.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded dc50c8080dd2c95acf5db166dce13e3f.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded GettyImages-1067769180.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Successfully uploaded IMG_0408hk.jpg to S3 bucket modemixer-images
# Document inserted successfully
# Images uploaded successfully
